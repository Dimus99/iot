# %%
#ml
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 4.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=d3432c1a7d94e861a1fa5cbff3ab3fa31b9b85a0d7538607f5cad139cb1a4161
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="fzlhgskjf18HweN49jyc")
project = rf.workspace().project("jacket-detection-gugey")
model = project.version(1).model

# infer on a local image
print(model.predict("Beauty 1_00000.jpg", confidence=40, overlap=30).json())

# visualize your prediction
# model.predict("your_image.jpg", confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f1de18bbae15> in <cell line: 7>()
#       5
#       6 # infer on a local image
# ----> 7 print(model.predict("Beauty 1_00000.jpg", confidence=40, overlap=30).json())
#       8
#       9 # visualize your prediction
#
# /usr/local/lib/python3.9/dist-packages/roboflow/models/object_detection.py in predict(self, image_path, hosted, format, classes, overlap, confidence, stroke, labels)
#     158         if not hosted:
#     159             if type(image_path) is str:
# --> 160                 image = Image.open(image_path).convert("RGB")
#     161                 dimensions = image.size
#     162                 original_dimensions = copy.deepcopy(dimensions)
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="fzlhgskjf18HweN49jyc")
project = rf.workspace("nvidia").project("jacket-detection")
dataset = project.version(1).download("yolov8")

# %%
dataset.location
# Out:
# '/content/jacket-detection-1'

# %%
model.predict(dataset[0])

# %%
# каски

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd /content
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content

# %%
# import yaml

# dict_file = {'train':'/kaggle/working/Dataset/images/train' ,
#             'val': '/kaggle/working/Dataset/images/val',
#             'nc' : '3',
#             'names' : ['helmet','head','person']}

# with open('yolov5/data/hard_head.yaml', 'w+') as file:
#     documents = yaml.dump(dict_file, file)

# %%
# !python yolov5/detect.py --source photos --weights best.pt --conf 0.25 --data yolov5/data/hard_head.yaml
# Out:
# detect: weights=['best.pt'], source=photos, data=yolov5/data/hard_head.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-135-g9dd0ad3 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7018216 parameters, 0 gradients
# image 1/2 /content/photos/test_img.jpeg: 384x640 1 helmet, 220.9ms
# image 2/2 /content/photos/without_helem.jpeg: 384x640 1 head, 204.4ms
# Speed: 0.5ms pre-process, 212.7ms inference, 0.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp9

# %%
from glob import glob
import matplotlib.pyplot as plt
testfiles = glob('yolov5/runs/detect/exp9/*')
# print(testfiles)

img = plt.imread(testfiles[0]) 
plt.imshow(img)    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img = plt.imread(testfiles[1]) 
plt.imshow(img)    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
