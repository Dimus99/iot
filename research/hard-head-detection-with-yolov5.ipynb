# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
from pathlib import Path
from xml.dom.minidom import parse
from shutil import copyfile
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
 #   for filename in filenames:
    #    print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Prepare Data for YOLOv5 Format

# %% [markdown]
# **Create directories to hold images and txt files for annotations (train , val ,test)**

# %%
# !mkdir -p Dataset/labels
# !mkdir -p Dataset/images

# %% [markdown]
# **classes**

# %%
classes = ['helmet','head','person']

# %% [markdown]
# **calculate ancor points and hiegt width of bonding boxes**

# %%
def convert_annot(size , box):
    x1 = int(box[0])
    y1 = int(box[1])
    x2 = int(box[2])
    y2 = int(box[3])

    dw = np.float32(1. / int(size[0]))
    dh = np.float32(1. / int(size[1]))

    w = x2 - x1
    h = y2 - y1
    x = x1 + (w / 2)
    y = y1 + (h / 2)

    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return [x, y, w, h]

# %%
def save_txt_file(img_jpg_file_name, size, img_box):
    save_file_name = '/kaggle/working/Dataset/labels/' +  img_jpg_file_name + '.txt'
    print(save_file_name)
    #file_path = open(save_file_name, "a+")
    with open(save_file_name ,'a+') as file_path:
        for box in img_box:

            cls_num = classes.index(box[0])

            new_box = convert_annot(size, box[1:])

            file_path.write(f"{cls_num} {new_box[0]} {new_box[1]} {new_box[2]} {new_box[3]}\n")

        file_path.flush()
        file_path.close()

# %%
def get_xml_data(file_path, img_xml_file):
    img_path = file_path + '/' + img_xml_file + '.xml'
    #print(img_path)

    dom = parse(img_path)
    root = dom.documentElement
    img_name = root.getElementsByTagName("filename")[0].childNodes[0].data
    img_size = root.getElementsByTagName("size")[0]
    objects = root.getElementsByTagName("object")
    img_w = img_size.getElementsByTagName("width")[0].childNodes[0].data
    img_h = img_size.getElementsByTagName("height")[0].childNodes[0].data
    img_c = img_size.getElementsByTagName("depth")[0].childNodes[0].data
   
    img_box = []
    for box in objects:
        cls_name = box.getElementsByTagName("name")[0].childNodes[0].data
        x1 = int(box.getElementsByTagName("xmin")[0].childNodes[0].data)
        y1 = int(box.getElementsByTagName("ymin")[0].childNodes[0].data)
        x2 = int(box.getElementsByTagName("xmax")[0].childNodes[0].data)
        y2 = int(box.getElementsByTagName("ymax")[0].childNodes[0].data)
        
        img_jpg_file_name = img_xml_file + '.jpg'
        img_box.append([cls_name, x1, y1, x2, y2])
  

    # test_dataset_box_feature(img_jpg_file_name, img_box)
    save_txt_file(img_xml_file, [img_w, img_h], img_box)

# %%
# !ls /kaggle/working/Dataset/labels

# %%
files = os.listdir('/kaggle/input/hard-hat-detection/annotations')
for file in files:
    print("file name: ", file)
    file_xml = file.split(".")
    print(file_xml[0])
    get_xml_data('/kaggle/input/hard-hat-detection/annotations', file_xml[0])
# Out:
# file name:  hard_hat_workers1531.xml
# hard_hat_workers1531
# /kaggle/working/Dataset/labels/hard_hat_workers1531.txt
# file name:  hard_hat_workers4092.xml
# hard_hat_workers4092
# /kaggle/working/Dataset/labels/hard_hat_workers4092.txt
# file name:  hard_hat_workers2006.xml
# hard_hat_workers2006
# /kaggle/working/Dataset/labels/hard_hat_workers2006.txt
# file name:  hard_hat_workers3414.xml
# hard_hat_workers3414
# /kaggle/working/Dataset/labels/hard_hat_workers3414.txt
# file name:  hard_hat_workers4190.xml
# hard_hat_workers4190
# /kaggle/working/Dataset/labels/hard_hat_workers4190.txt
# file name:  hard_hat_workers324.xml
# hard_hat_workers324
# /kaggle/working/Dataset/labels/hard_hat_workers324.txt
# file name:  hard_hat_workers4181.xml
# hard_hat_workers4181
# /kaggle/working/Dataset/labels/hard_hat_workers4181.txt
# file name:  hard_hat_workers3912.xml
# hard_hat_workers3912
# /kaggle/working/Dataset/labels/hard_hat_workers3912.txt
# file name:  hard_hat_workers3704.xml
# hard_hat_workers3704
# /kaggle/working/Dataset/labels/hard_hat_workers3704.txt
# file name:  hard_hat_workers4740.xml
# hard_hat_workers4740
# /kaggle/working/Dataset/labels/hard_hat_workers4740.txt
# file name:  hard_hat_workers714.xml
# hard_hat_workers714
# /kaggle/working/Dataset/labels/hard_hat_workers714.txt
# file name:  hard_hat_workers486.xml
# hard_hat_workers486
# /kaggle/working/Dataset/labels/hard_hat_workers486.txt
# file name:  hard_hat_workers1331.xml
# hard_hat_workers1331
# /kaggle/working/Dataset/labels/hard_hat_workers1331.txt
# file name:  hard_hat_workers3623.xml
# hard_hat_workers3623
# /kaggle/working/Dataset/labels/hard_hat_workers3623.txt
# file name:  hard_hat_workers3006.xml
# hard_hat_workers3006
# /kaggle/working/Dataset/labels/hard_hat_workers3006.txt
# file name:  hard_hat_workers3449.xml
# hard_hat_workers3449
# /kaggle/working/Dataset/labels/hard_hat_workers3449.txt
# file name:  hard_hat_workers1491.xml
# hard_hat_workers1491
# /kaggle/working/Dataset/labels/hard_hat_workers1491.txt
# file name:  hard_hat_workers4421.xml
# hard_hat_workers4421
# /kaggle/working/Dataset/labels/hard_hat_workers4421.txt
# file name:  hard_hat_workers4502.xml
# hard_hat_workers4502
# /kaggle/working/Dataset/labels/hard_hat_workers4502.txt
# file name:  hard_hat_workers2018.xml
# hard_hat_workers2018
# /kaggle/working/Dataset/labels/hard_hat_workers2018.txt
# file name:  hard_hat_workers3268.xml
# hard_hat_workers3268
# /kaggle/working/Dataset/labels/hard_hat_workers3268.txt
# file name:  hard_hat_workers168.xml
# hard_hat_workers168
# /kaggle/working/Dataset/labels/hard_hat_workers168.txt
# file name:  hard_hat_workers3142.xml
# hard_hat_workers3142
# /kaggle/working/Dataset/labels/hard_hat_workers3142.txt
# file name:  hard_hat_workers4812.xml
# hard_hat_workers4812
# /kaggle/working/Dataset/labels/hard_hat_workers4812.txt
# file name:  hard_hat_workers1251.xml
# hard_hat_workers1251
# /kaggle/working/Dataset/labels/hard_hat_workers1251.txt
# file name:  hard_hat_workers2196.xml
# hard_hat_workers2196
# /kaggle/working/Dataset/labels/hard_hat_workers2196.txt
# file name:  hard_hat_workers2390.xml
# hard_hat_workers2390
# /kaggle/working/Dataset/labels/hard_hat_workers2390.txt
# file name:  hard_hat_workers3095.xml
# hard_hat_workers3095
# /kaggle/working/Dataset/labels/hard_hat_workers3095.txt
# file name:  hard_hat_workers268.xml
# /kaggle/working/Dataset/labels/hard_hat_workers1657.txt
# file name:  hard_hat_workers2156.xml
# hard_hat_workers2156
# /kaggle/working/Dataset/labels/hard_hat_workers2156.txt
# file name:  hard_hat_workers4442.xml
# hard_hat_workers4442
# /kaggle/working/Dataset/labels/hard_hat_workers4442.txt
# file name:  hard_hat_workers2781.xml
# hard_hat_workers2781
# /kaggle/working/Dataset/labels/hard_hat_workers2781.txt
# file name:  hard_hat_workers1367.xml
# hard_hat_workers1367
# /kaggle/working/Dataset/labels/hard_hat_workers1367.txt
# file name:  hard_hat_workers472.xml
# hard_hat_workers472
# /kaggle/working/Dataset/labels/hard_hat_workers472.txt
# file name:  hard_hat_workers3795.xml
# hard_hat_workers3795
# /kaggle/working/Dataset/labels/hard_hat_workers3795.txt
# file name:  hard_hat_workers2149.xml
# hard_hat_workers2149
# /kaggle/working/Dataset/labels/hard_hat_workers2149.txt
# file name:  hard_hat_workers1339.xml
# hard_hat_workers1339
# /kaggle/working/Dataset/labels/hard_hat_workers1339.txt
# file name:  hard_hat_workers2853.xml
# hard_hat_workers2853
# /kaggle/working/Dataset/labels/hard_hat_workers2853.txt
# file name:  hard_hat_workers4688.xml
# hard_hat_workers4688
# /kaggle/working/Dataset/labels/hard_hat_workers4688.txt
# file name:  hard_hat_workers355.xml
# hard_hat_workers355
# /kaggle/working/Dataset/labels/hard_hat_workers355.txt
# file name:  hard_hat_workers4822.xml
# hard_hat_workers4822
# /kaggle/working/Dataset/labels/hard_hat_workers4822.txt
# file name:  hard_hat_workers3762.xml
# hard_hat_workers3762
# /kaggle/working/Dataset/labels/hard_hat_workers3762.txt
# file name:  hard_hat_workers2128.xml
# hard_hat_workers2128
# /kaggle/working/Dataset/labels/hard_hat_workers2128.txt
# file name:  hard_hat_workers2163.xml
# hard_hat_workers2163
# /kaggle/working/Dataset/labels/hard_hat_workers2163.txt
# file name:  hard_hat_workers3889.xml
# hard_hat_workers3889
# /kaggle/working/Dataset/labels/hard_hat_workers3889.txt
# file name:  hard_hat_workers2537.xml
# hard_hat_workers2537
# /kaggle/working/Dataset/labels/hard_hat_workers2537.txt
# file name:  hard_hat_workers4861.xml
# hard_hat_workers4861
# /kaggle/working/Dataset/labels/hard_hat_workers4861.txt
# file name:  hard_hat_workers887.xml
# hard_hat_workers887
# /kaggle/working/Dataset/labels/hard_hat_workers887.txt
# file name:  hard_hat_workers2471.xml
# hard_hat_workers2471
# /kaggle/working/Dataset/labels/hard_hat_workers2471.txt
# file name:  hard_hat_workers3766.xml
# hard_hat_workers3766
# /kaggle/working/Dataset/labels/hard_hat_workers3766.txt
# file name:  hard_hat_workers2164.xml
# hard_hat_workers2164
# /kaggle/working/Dataset/labels/hard_hat_workers2164.txt
# file name:  hard_hat_workers3032.xml
# hard_hat_workers3032
# /kaggle/working/Dataset/labels/hard_hat_workers3032.txt
# file name:  hard_hat_workers1918.xml
# hard_hat_workers1918
# /kaggle/working/Dataset/labels/hard_hat_workers1918.txt
# file name:  hard_hat_workers245.xml
# hard_hat_workers245
# hard_hat_workers4509
# /kaggle/working/Dataset/labels/hard_hat_workers4509.txt
# file name:  hard_hat_workers625.xml
# hard_hat_workers625
# /kaggle/working/Dataset/labels/hard_hat_workers625.txt
# file name:  hard_hat_workers645.xml
# hard_hat_workers645
# /kaggle/working/Dataset/labels/hard_hat_workers645.txt
# file name:  hard_hat_workers3634.xml
# hard_hat_workers3634
# /kaggle/working/Dataset/labels/hard_hat_workers3634.txt
# file name:  hard_hat_workers1982.xml
# hard_hat_workers1982
# /kaggle/working/Dataset/labels/hard_hat_workers1982.txt
# file name:  hard_hat_workers3624.xml
# hard_hat_workers3624
# /kaggle/working/Dataset/labels/hard_hat_workers3624.txt
# file name:  hard_hat_workers4070.xml
# hard_hat_workers4070
# /kaggle/working/Dataset/labels/hard_hat_workers4070.txt
# file name:  hard_hat_workers2668.xml
# hard_hat_workers2668
# /kaggle/working/Dataset/labels/hard_hat_workers2668.txt
# file name:  hard_hat_workers999.xml
# hard_hat_workers999
# /kaggle/working/Dataset/labels/hard_hat_workers999.txt
# file name:  hard_hat_workers4032.xml
# hard_hat_workers4032
# /kaggle/working/Dataset/labels/hard_hat_workers4032.txt
# file name:  hard_hat_workers359.xml
# hard_hat_workers359
# /kaggle/working/Dataset/labels/hard_hat_workers359.txt
# file name:  hard_hat_workers2261.xml
# hard_hat_workers2261
# /kaggle/working/Dataset/labels/hard_hat_workers2261.txt
# file name:  hard_hat_workers2204.xml
# hard_hat_workers2204
# /kaggle/working/Dataset/labels/hard_hat_workers2204.txt
# file name:  hard_hat_workers2284.xml
# hard_hat_workers2284
# /kaggle/working/Dataset/labels/hard_hat_workers2284.txt
# file name:  hard_hat_workers4063.xml
# hard_hat_workers4063
# /kaggle/working/Dataset/labels/hard_hat_workers4063.txt
# file name:  hard_hat_workers1206.xml
# hard_hat_workers1206
# /kaggle/working/Dataset/labels/hard_hat_workers1206.txt
# file name:  hard_hat_workers43.xml
# hard_hat_workers43
# /kaggle/working/Dataset/labels/hard_hat_workers43.txt
# file name:  hard_hat_workers4206.xml
# hard_hat_workers4206
# /kaggle/working/Dataset/labels/hard_hat_workers4206.txt
# file name:  hard_hat_workers69.xml
# hard_hat_workers69
# /kaggle/working/Dataset/labels/hard_hat_workers69.txt
# file name:  hard_hat_workers1732.xml
# hard_hat_workers1732
# /kaggle/working/Dataset/labels/hard_hat_workers1732.txt
# file name:  hard_hat_workers2229.xml
# hard_hat_workers2229
# /kaggle/working/Dataset/labels/hard_hat_workers2229.txt
# file name:  hard_hat_workers455.xml
# hard_hat_workers455
# /kaggle/working/Dataset/labels/hard_hat_workers455.txt
# file name:  hard_hat_workers2575.xml
# hard_hat_workers2575
# /kaggle/working/Dataset/labels/hard_hat_workers2575.txt
# file name:  hard_hat_workers779.xml
# hard_hat_workers779
# /kaggle/working/Dataset/labels/hard_hat_workers779.txt
# file name:  hard_hat_workers2293.xml
# hard_hat_workers2293
# /kaggle/working/Dataset/labels/hard_hat_workers2293.txt
# file name:  hard_hat_workers3173.xml
# hard_hat_workers3173
# file name:  hard_hat_workers1869.xml
# hard_hat_workers1869
# /kaggle/working/Dataset/labels/hard_hat_workers1869.txt
# file name:  hard_hat_workers1292.xml
# hard_hat_workers1292
# /kaggle/working/Dataset/labels/hard_hat_workers1292.txt
# file name:  hard_hat_workers2926.xml
# hard_hat_workers2926
# /kaggle/working/Dataset/labels/hard_hat_workers2926.txt
# file name:  hard_hat_workers3822.xml
# hard_hat_workers3822
# /kaggle/working/Dataset/labels/hard_hat_workers3822.txt
# file name:  hard_hat_workers1590.xml
# hard_hat_workers1590
# /kaggle/working/Dataset/labels/hard_hat_workers1590.txt
# file name:  hard_hat_workers2230.xml
# hard_hat_workers2230
# /kaggle/working/Dataset/labels/hard_hat_workers2230.txt
# file name:  hard_hat_workers1486.xml
# hard_hat_workers1486
# /kaggle/working/Dataset/labels/hard_hat_workers1486.txt
# file name:  hard_hat_workers3091.xml
# hard_hat_workers3091
# /kaggle/working/Dataset/labels/hard_hat_workers3091.txt
# file name:  hard_hat_workers3724.xml
# hard_hat_workers3724
# /kaggle/working/Dataset/labels/hard_hat_workers3724.txt
# file name:  hard_hat_workers130.xml
# hard_hat_workers130
# /kaggle/working/Dataset/labels/hard_hat_workers130.txt
# file name:  hard_hat_workers2297.xml
# hard_hat_workers2297
# /kaggle/working/Dataset/labels/hard_hat_workers2297.txt
# file name:  hard_hat_workers1063.xml
# hard_hat_workers1063
# /kaggle/working/Dataset/labels/hard_hat_workers1063.txt
# file name:  hard_hat_workers655.xml
# hard_hat_workers655
# /kaggle/working/Dataset/labels/hard_hat_workers655.txt
# file name:  hard_hat_workers3973.xml
# hard_hat_workers3973
# /kaggle/working/Dataset/labels/hard_hat_workers3973.txt
# file name:  hard_hat_workers883.xml
# hard_hat_workers883
# /kaggle/working/Dataset/labels/hard_hat_workers883.txt
# file name:  hard_hat_workers4263.xml
# hard_hat_workers4263
# ...
# file name:  hard_hat_workers2943.xml
# hard_hat_workers2943
# /kaggle/working/Dataset/labels/hard_hat_workers2943.txt
# file name:  hard_hat_workers4369.xml
# hard_hat_workers4369
# /kaggle/working/Dataset/labels/hard_hat_workers4369.txt
# file name:  hard_hat_workers978.xml
# hard_hat_workers978
# /kaggle/working/Dataset/labels/hard_hat_workers978.txt
# file name:  hard_hat_workers730.xml
# hard_hat_workers730
# /kaggle/working/Dataset/labels/hard_hat_workers730.txt
# file name:  hard_hat_workers3431.xml
# hard_hat_workers3431
# /kaggle/working/Dataset/labels/hard_hat_workers3431.txt
# file name:  hard_hat_workers77.xml
# hard_hat_workers77
# /kaggle/working/Dataset/labels/hard_hat_workers77.txt
# file name:  hard_hat_workers3251.xml
# hard_hat_workers3251
# /kaggle/working/Dataset/labels/hard_hat_workers3251.txt
# file name:  hard_hat_workers4147.xml
# hard_hat_workers4147
# /kaggle/working/Dataset/labels/hard_hat_workers4147.txt
# file name:  hard_hat_workers1471.xml
# hard_hat_workers1471
# /kaggle/working/Dataset/labels/hard_hat_workers1471.txt
# file name:  hard_hat_workers3230.xml
# hard_hat_workers3230
# /kaggle/working/Dataset/labels/hard_hat_workers3230.txt
# file name:  hard_hat_workers2274.xml
# hard_hat_workers2274
# /kaggle/working/Dataset/labels/hard_hat_workers2274.txt
# file name:  hard_hat_workers1342.xml
# hard_hat_workers1342
# /kaggle/working/Dataset/labels/hard_hat_workers1342.txt
# file name:  hard_hat_workers905.xml
# hard_hat_workers905
# /kaggle/working/Dataset/labels/hard_hat_workers905.txt
# file name:  hard_hat_workers2704.xml
# hard_hat_workers2704
# /kaggle/working/Dataset/labels/hard_hat_workers2704.txt
# file name:  hard_hat_workers1964.xml
# hard_hat_workers1964
# /kaggle/working/Dataset/labels/hard_hat_workers1964.txt
# file name:  hard_hat_workers2214.xml
# hard_hat_workers2214
# /kaggle/working/Dataset/labels/hard_hat_workers2214.txt
# file name:  hard_hat_workers4749.xml
# hard_hat_workers4749
# /kaggle/working/Dataset/labels/hard_hat_workers4749.txt
# file name:  hard_hat_workers437.xml
# hard_hat_workers437
# /kaggle/working/Dataset/labels/hard_hat_workers437.txt
# file name:  hard_hat_workers1143.xml
# hard_hat_workers1143
# /kaggle/working/Dataset/labels/hard_hat_workers1143.txt
# file name:  hard_hat_workers1839.xml
# hard_hat_workers1839
# /kaggle/working/Dataset/labels/hard_hat_workers1839.txt
# file name:  hard_hat_workers2814.xml
# hard_hat_workers2814
# /kaggle/working/Dataset/labels/hard_hat_workers2814.txt
# file name:  hard_hat_workers4052.xml
# hard_hat_workers4052
# /kaggle/working/Dataset/labels/hard_hat_workers4052.txt
# file name:  hard_hat_workers1349.xml
# hard_hat_workers1349
# /kaggle/working/Dataset/labels/hard_hat_workers1349.txt
# file name:  hard_hat_workers1421.xml
# hard_hat_workers1421
# /kaggle/working/Dataset/labels/hard_hat_workers1421.txt
# file name:  hard_hat_workers1887.xml
# hard_hat_workers1887
# /kaggle/working/Dataset/labels/hard_hat_workers1887.txt
# file name:  hard_hat_workers204.xml
# hard_hat_workers204
# /kaggle/working/Dataset/labels/hard_hat_workers204.txt
# file name:  hard_hat_workers4945.xml
# hard_hat_workers4945
# /kaggle/working/Dataset/labels/hard_hat_workers4945.txt
# file name:  hard_hat_workers3537.xml
# hard_hat_workers3537
# /kaggle/working/Dataset/labels/hard_hat_workers3537.txt
# file name:  hard_hat_workers1005.xml
# hard_hat_workers1005
# /kaggle/working/Dataset/labels/hard_hat_workers1005.txt
# file name:  hard_hat_workers2408.xml
# hard_hat_workers2408
# /kaggle/working/Dataset/labels/hard_hat_workers2408.txt
# file name:  hard_hat_workers3633.xml
# hard_hat_workers3633
# /kaggle/working/Dataset/labels/hard_hat_workers3633.txt
# file name:  hard_hat_workers1209.xml
# hard_hat_workers1209
# /kaggle/working/Dataset/labels/hard_hat_workers1209.txt
# file name:  hard_hat_workers2924.xml
# hard_hat_workers2924
# /kaggle/working/Dataset/labels/hard_hat_workers2924.txt
# file name:  hard_hat_workers154.xml
# hard_hat_workers154
# /kaggle/working/Dataset/labels/hard_hat_workers154.txt
# file name:  hard_hat_workers3628.xml
# hard_hat_workers3628
# /kaggle/working/Dataset/labels/hard_hat_workers3628.txt
# file name:  hard_hat_workers1797.xml
# hard_hat_workers1797
# /kaggle/working/Dataset/labels/hard_hat_workers1797.txt
# file name:  hard_hat_workers1290.xml
# hard_hat_workers1290
# /kaggle/working/Dataset/labels/hard_hat_workers1290.txt
# file name:  hard_hat_workers4895.xml
# hard_hat_workers4895
# /kaggle/working/Dataset/labels/hard_hat_workers4895.txt
# file name:  hard_hat_workers4804.xml
# hard_hat_workers4804
# /kaggle/working/Dataset/labels/hard_hat_workers4804.txt
# file name:  hard_hat_workers3577.xml
# hard_hat_workers3577
# /kaggle/working/Dataset/labels/hard_hat_workers3577.txt
# file name:  hard_hat_workers929.xml
# hard_hat_workers929
# /kaggle/working/Dataset/labels/hard_hat_workers929.txt
# file name:  hard_hat_workers3840.xml
# hard_hat_workers3840
# /kaggle/working/Dataset/labels/hard_hat_workers3840.txt
# file name:  hard_hat_workers1230.xml
# hard_hat_workers1230
# /kaggle/working/Dataset/labels/hard_hat_workers1230.txt
# file name:  hard_hat_workers782.xml
# hard_hat_workers782
# /kaggle/working/Dataset/labels/hard_hat_workers782.txt
# file name:  hard_hat_workers1751.xml
# hard_hat_workers1751
# /kaggle/working/Dataset/labels/hard_hat_workers1751.txt
# file name:  hard_hat_workers1706.xml
# hard_hat_workers1706
# /kaggle/working/Dataset/labels/hard_hat_workers1706.txt
# file name:  hard_hat_workers4848.xml
# hard_hat_workers4848
# /kaggle/working/Dataset/labels/hard_hat_workers4848.txt
# file name:  hard_hat_workers404.xml
# hard_hat_workers404
# /kaggle/working/Dataset/labels/hard_hat_workers404.txt
# file name:  hard_hat_workers2305.xml
# hard_hat_workers2305
# /kaggle/working/Dataset/labels/hard_hat_workers2305.txt
# file name:  hard_hat_workers839.xml
# hard_hat_workers839
# /kaggle/working/Dataset/labels/hard_hat_workers839.txt
# file name:  hard_hat_workers3610.xml
# hard_hat_workers3610
# /kaggle/working/Dataset/labels/hard_hat_workers3610.txt
# file name:  hard_hat_workers3136.xml
# hard_hat_workers3136
# /kaggle/working/Dataset/labels/hard_hat_workers3136.txt
# file name:  hard_hat_workers2576.xml
# hard_hat_workers2576
# /kaggle/working/Dataset/labels/hard_hat_workers2576.txt
# file name:  hard_hat_workers1220.xml
# hard_hat_workers1220
# /kaggle/working/Dataset/labels/hard_hat_workers1220.txt
# file name:  hard_hat_workers4345.xml
# hard_hat_workers4345
# /kaggle/working/Dataset/labels/hard_hat_workers4345.txt
# file name:  hard_hat_workers3189.xml
# hard_hat_workers3189
# /kaggle/working/Dataset/labels/hard_hat_workers3189.txt
# file name:  hard_hat_workers3370.xml
# hard_hat_workers3370
# /kaggle/working/Dataset/labels/hard_hat_workers3370.txt
# file name:  hard_hat_workers2527.xml
# hard_hat_workers2527
# /kaggle/working/Dataset/labels/hard_hat_workers2527.txt
# file name:  hard_hat_workers571.xml
# hard_hat_workers571
# /kaggle/working/Dataset/labels/hard_hat_workers571.txt
# file name:  hard_hat_workers4729.xml
# hard_hat_workers4729
# /kaggle/working/Dataset/labels/hard_hat_workers4729.txt
# file name:  hard_hat_workers3677.xml
# hard_hat_workers3677
# /kaggle/working/Dataset/labels/hard_hat_workers3677.txt
# file name:  hard_hat_workers738.xml
# hard_hat_workers738
# /kaggle/working/Dataset/labels/hard_hat_workers738.txt
# file name:  hard_hat_workers3377.xml
# hard_hat_workers3377
# /kaggle/working/Dataset/labels/hard_hat_workers3377.txt
# file name:  hard_hat_workers4362.xml
# hard_hat_workers4362
# /kaggle/working/Dataset/labels/hard_hat_workers4362.txt
# file name:  hard_hat_workers1291.xml
# hard_hat_workers1291
# /kaggle/working/Dataset/labels/hard_hat_workers1291.txt
# file name:  hard_hat_workers2972.xml
# hard_hat_workers2972
# /kaggle/working/Dataset/labels/hard_hat_workers2972.txt
# file name:  hard_hat_workers3562.xml
# hard_hat_workers3562
# /kaggle/working/Dataset/labels/hard_hat_workers3562.txt
# file name:  hard_hat_workers2596.xml
# hard_hat_workers2596
# /kaggle/working/Dataset/labels/hard_hat_workers2596.txt
# file name:  hard_hat_workers477.xml
# hard_hat_workers477
# /kaggle/working/Dataset/labels/hard_hat_workers477.txt
# file name:  hard_hat_workers4776.xml
# hard_hat_workers4776
# /kaggle/working/Dataset/labels/hard_hat_workers4776.txt
# file name:  hard_hat_workers1585.xml
# hard_hat_workers1585
# /kaggle/working/Dataset/labels/hard_hat_workers1585.txt
# file name:  hard_hat_workers2378.xml
# hard_hat_workers2378
# /kaggle/working/Dataset/labels/hard_hat_workers2378.txt
# file name:  hard_hat_workers3647.xml
# hard_hat_workers3647
# /kaggle/working/Dataset/labels/hard_hat_workers3647.txt
# file name:  hard_hat_workers821.xml
# hard_hat_workers821
# /kaggle/working/Dataset/labels/hard_hat_workers821.txt
# file name:  hard_hat_workers3020.xml
# hard_hat_workers3020
# /kaggle/working/Dataset/labels/hard_hat_workers3020.txt
# file name:  hard_hat_workers4710.xml
# hard_hat_workers4710
# /kaggle/working/Dataset/labels/hard_hat_workers4710.txt
# file name:  hard_hat_workers3698.xml
# hard_hat_workers3698
# /kaggle/working/Dataset/labels/hard_hat_workers3698.txt
# file name:  hard_hat_workers4707.xml
# hard_hat_workers4707
# /kaggle/working/Dataset/labels/hard_hat_workers4707.txt
# file name:  hard_hat_workers442.xml
# hard_hat_workers442
# /kaggle/working/Dataset/labels/hard_hat_workers442.txt
# file name:  hard_hat_workers1802.xml
# hard_hat_workers1802
# /kaggle/working/Dataset/labels/hard_hat_workers1802.txt
# file name:  hard_hat_workers207.xml
# hard_hat_workers207
# /kaggle/working/Dataset/labels/hard_hat_workers207.txt
# file name:  hard_hat_workers4498.xml
# hard_hat_workers4498
# /kaggle/working/Dataset/labels/hard_hat_workers4498.txt
# file name:  hard_hat_workers3079.xml
# hard_hat_workers3079
# /kaggle/working/Dataset/labels/hard_hat_workers3079.txt
# file name:  hard_hat_workers4723.xml
# hard_hat_workers4723
# /kaggle/working/Dataset/labels/hard_hat_workers4723.txt
# file name:  hard_hat_workers4781.xml
# hard_hat_workers4781
# /kaggle/working/Dataset/labels/hard_hat_workers4781.txt
# file name:  hard_hat_workers2984.xml
# hard_hat_workers2984
# /kaggle/working/Dataset/labels/hard_hat_workers2984.txt
# file name:  hard_hat_workers4912.xml
# hard_hat_workers4912
# /kaggle/working/Dataset/labels/hard_hat_workers4912.txt
# file name:  hard_hat_workers637.xml
# hard_hat_workers637
# /kaggle/working/Dataset/labels/hard_hat_workers637.txt
# file name:  hard_hat_workers4558.xml
# hard_hat_workers4558
# /kaggle/working/Dataset/labels/hard_hat_workers4558.txt
# file name:  hard_hat_workers2607.xml
# hard_hat_workers2607
# /kaggle/working/Dataset/labels/hard_hat_workers2607.txt
# file name:  hard_hat_workers2923.xml
# hard_hat_workers2923
# /kaggle/working/Dataset/labels/hard_hat_workers2923.txt
# file name:  hard_hat_workers2325.xml
# hard_hat_workers2325
# /kaggle/working/Dataset/labels/hard_hat_workers2325.txt
# file name:  hard_hat_workers2927.xml
# hard_hat_workers2927
# /kaggle/working/Dataset/labels/hard_hat_workers2927.txt
# file name:  hard_hat_workers1937.xml
# hard_hat_workers1937
# /kaggle/working/Dataset/labels/hard_hat_workers1937.txt
# file name:  hard_hat_workers4632.xml
# hard_hat_workers4632
# /kaggle/working/Dataset/labels/hard_hat_workers4632.txt
# file name:  hard_hat_workers993.xml
# hard_hat_workers993
# /kaggle/working/Dataset/labels/hard_hat_workers993.txt
# file name:  hard_hat_workers1881.xml
# hard_hat_workers1881
# /kaggle/working/Dataset/labels/hard_hat_workers1881.txt
# file name:  hard_hat_workers220.xml
# hard_hat_workers220
# /kaggle/working/Dataset/labels/hard_hat_workers220.txt
# file name:  hard_hat_workers337.xml
# hard_hat_workers337
# /kaggle/working/Dataset/labels/hard_hat_workers337.txt
# file name:  hard_hat_workers766.xml
# hard_hat_workers766
# /kaggle/working/Dataset/labels/hard_hat_workers766.txt
# file name:  hard_hat_workers2716.xml
# hard_hat_workers2716
# /kaggle/working/Dataset/labels/hard_hat_workers2716.txt
# file name:  hard_hat_workers3110.xml
# hard_hat_workers3110
# /kaggle/working/Dataset/labels/hard_hat_workers3110.txt
# file name:  hard_hat_workers2178.xml
# hard_hat_workers2178
# /kaggle/working/Dataset/labels/hard_hat_workers2178.txt
# file name:  hard_hat_workers3049.xml
# hard_hat_workers3049
# /kaggle/working/Dataset/labels/hard_hat_workers3049.txt
# file name:  hard_hat_workers2800.xml
# hard_hat_workers2800
# /kaggle/working/Dataset/labels/hard_hat_workers2800.txt
# file name:  hard_hat_workers4253.xml
# hard_hat_workers4253
# /kaggle/working/Dataset/labels/hard_hat_workers4253.txt
# file name:  hard_hat_workers1700.xml
# hard_hat_workers1700
# /kaggle/working/Dataset/labels/hard_hat_workers1700.txt
# file name:  hard_hat_workers973.xml
# hard_hat_workers973
# /kaggle/working/Dataset/labels/hard_hat_workers973.txt
# file name:  hard_hat_workers3260.xml
# hard_hat_workers3260
# /kaggle/working/Dataset/labels/hard_hat_workers3260.txt
# file name:  hard_hat_workers1281.xml
# hard_hat_workers1281
# /kaggle/working/Dataset/labels/hard_hat_workers1281.txt
# file name:  hard_hat_workers3827.xml
# hard_hat_workers3827
# /kaggle/working/Dataset/labels/hard_hat_workers3827.txt
# file name:  hard_hat_workers2892.xml
# hard_hat_workers2892
# /kaggle/working/Dataset/labels/hard_hat_workers2892.txt
# file name:  hard_hat_workers3985.xml
# hard_hat_workers3985
# /kaggle/working/Dataset/labels/hard_hat_workers3985.txt
# file name:  hard_hat_workers1614.xml
# hard_hat_workers1614
# /kaggle/working/Dataset/labels/hard_hat_workers1614.txt
# file name:  hard_hat_workers3493.xml
# hard_hat_workers3493
# /kaggle/working/Dataset/labels/hard_hat_workers3493.txt
# file name:  hard_hat_workers2021.xml
# hard_hat_workers2021
# /kaggle/working/Dataset/labels/hard_hat_workers2021.txt
# file name:  hard_hat_workers2346.xml
# hard_hat_workers2346
# /kaggle/working/Dataset/labels/hard_hat_workers2346.txt
# file name:  hard_hat_workers1861.xml
# hard_hat_workers1861
# /kaggle/working/Dataset/labels/hard_hat_workers1861.txt
# file name:  hard_hat_workers2748.xml
# hard_hat_workers2748
# /kaggle/working/Dataset/labels/hard_hat_workers2748.txt
# file name:  hard_hat_workers1519.xml
# hard_hat_workers1519
# /kaggle/working/Dataset/labels/hard_hat_workers1519.txt
# file name:  hard_hat_workers3709.xml
# hard_hat_workers3709
# /kaggle/working/Dataset/labels/hard_hat_workers3709.txt
# file name:  hard_hat_workers1801.xml
# hard_hat_workers1801
# /kaggle/working/Dataset/labels/hard_hat_workers1801.txt
# file name:  hard_hat_workers4034.xml
# hard_hat_workers4034
# /kaggle/working/Dataset/labels/hard_hat_workers4034.txt
# file name:  hard_hat_workers1885.xml
# hard_hat_workers1885
# /kaggle/working/Dataset/labels/hard_hat_workers1885.txt
# file name:  hard_hat_workers94.xml
# hard_hat_workers94
# /kaggle/working/Dataset/labels/hard_hat_workers94.txt
# file name:  hard_hat_workers3583.xml
# hard_hat_workers3583
# /kaggle/working/Dataset/labels/hard_hat_workers3583.txt
# file name:  hard_hat_workers3842.xml
# hard_hat_workers3842
# /kaggle/working/Dataset/labels/hard_hat_workers3842.txt
# file name:  hard_hat_workers4972.xml
# hard_hat_workers4972
# /kaggle/working/Dataset/labels/hard_hat_workers4972.txt
# file name:  hard_hat_workers2206.xml
# hard_hat_workers2206
# /kaggle/working/Dataset/labels/hard_hat_workers2206.txt
# file name:  hard_hat_workers4915.xml
# hard_hat_workers4915
# /kaggle/working/Dataset/labels/hard_hat_workers4915.txt
# file name:  hard_hat_workers210.xml
# hard_hat_workers210
# /kaggle/working/Dataset/labels/hard_hat_workers210.txt
# file name:  hard_hat_workers2950.xml
# hard_hat_workers2950
# /kaggle/working/Dataset/labels/hard_hat_workers2950.txt
# file name:  hard_hat_workers4600.xml
# hard_hat_workers4600
# /kaggle/working/Dataset/labels/hard_hat_workers4600.txt
# file name:  hard_hat_workers3322.xml
# hard_hat_workers3322
# /kaggle/working/Dataset/labels/hard_hat_workers3322.txt
# file name:  hard_hat_workers4998.xml
# hard_hat_workers4998
# /kaggle/working/Dataset/labels/hard_hat_workers4998.txt
# file name:  hard_hat_workers331.xml
# hard_hat_workers331
# /kaggle/working/Dataset/labels/hard_hat_workers331.txt
# file name:  hard_hat_workers3012.xml
# hard_hat_workers3012
# /kaggle/working/Dataset/labels/hard_hat_workers3012.txt
# file name:  hard_hat_workers1455.xml
# hard_hat_workers1455
# /kaggle/working/Dataset/labels/hard_hat_workers1455.txt
# file name:  hard_hat_workers2764.xml
# hard_hat_workers2764
# /kaggle/working/Dataset/labels/hard_hat_workers2764.txt
# file name:  hard_hat_workers2465.xml
# hard_hat_workers2465
# /kaggle/working/Dataset/labels/hard_hat_workers2465.txt
# file name:  hard_hat_workers4529.xml
# hard_hat_workers4529
# /kaggle/working/Dataset/labels/hard_hat_workers4529.txt

# %% [markdown]
# # split train val test

# %%
from sklearn.model_selection import train_test_split
image_list = os.listdir('/kaggle/input/hard-hat-detection/images')
train_list, test_list = train_test_split(image_list, test_size=0.2, random_state=42)
val_list, test_list = train_test_split(test_list, test_size=0.5, random_state=42)
print('total =',len(image_list))
print('train :',len(train_list))
print('val   :',len(val_list))
print('test  :',len(test_list))
# Out:
# total = 5000
# train : 4000
# val   : 500
# test  : 500

# %%
def copy_data(file_list, img_labels_root, imgs_source, mode):

    root_file = Path( '/kaggle/working/Dataset/images/'+  mode)
    if not root_file.exists():
        print(f"Path {root_file} does not exit")
        os.makedirs(root_file)

    root_file = Path('/kaggle/working/Dataset/labels/' + mode)
    if not root_file.exists():
        print(f"Path {root_file} does not exit")
        os.makedirs(root_file)

    for file in file_list:               
        img_name = file.replace('.png', '')        
        img_src_file = imgs_source + '/' + img_name + '.png'        
        label_src_file = img_labels_root + '/' + img_name + '.txt'

        #print(img_sor_file)
        #print(label_sor_file)
        # im = Image.open(rf"{img_sor_file}")
        # im.show()

        # Copy image
        DICT_DIR = '/kaggle/working/Dataset/images/'  + mode
        img_dict_file = DICT_DIR + '/' + img_name + '.png'

        copyfile(img_src_file, img_dict_file)

        # Copy label
        DICT_DIR = '/kaggle/working/Dataset/labels/' + mode
        img_dict_file = DICT_DIR + '/' + img_name + '.txt'
        copyfile(label_src_file, img_dict_file)

# %%
copy_data(train_list, '/kaggle/working/Dataset/labels', '/kaggle/input/hard-hat-detection/images', "train")
copy_data(val_list,   '/kaggle/working/Dataset/labels', '/kaggle/input/hard-hat-detection/images', "val")
copy_data(test_list,  '/kaggle/working/Dataset/labels', '/kaggle/input/hard-hat-detection/images', "test")
# Out:
# Path /kaggle/working/Dataset/images/train does not exit
# Path /kaggle/working/Dataset/labels/train does not exit
# Path /kaggle/working/Dataset/images/val does not exit
# Path /kaggle/working/Dataset/labels/val does not exit
# Path /kaggle/working/Dataset/images/test does not exit
# Path /kaggle/working/Dataset/labels/test does not exit

# %%
# !ls /kaggle/working/Dataset/images
# Out:
# test  train  val

# %% [markdown]
# # Get YOLOv5 model

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15378, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15378 (delta 4), reused 0 (delta 0), pack-reused 15368
# Receiving objects: 100% (15378/15378), 14.34 MiB | 21.10 MiB/s, done.
# Resolving deltas: 100% (10513/10513), done.
# /kaggle/working/yolov5

# %%
# !ls
# Out:
# CITATION.cff	 README.zh-CN.md  detect.py   requirements.txt	tutorial.ipynb
# CONTRIBUTING.md  benchmarks.py	  export.py   segment		utils
# LICENSE		 classify	  hubconf.py  setup.cfg		val.py
# README.md	 data		  models      train.py

# %% [markdown]
# **create yaml file for configuration**

# %%
import yaml

dict_file = {'train':'/kaggle/working/Dataset/images/train' ,
            'val': '/kaggle/working/Dataset/images/val',
            'nc' : '3',
            'names' : ['helmet','head','person']}

with open('/kaggle/working/yolov5/data/hard_head.yaml', 'w+') as file:
    documents = yaml.dump(dict_file, file)

# %% [markdown]
# # Train Net

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
# !python train.py --img 416 --batch 32 --epochs 30 --data data/hard_head.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data/hard_head.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: YOLOv5 requirements "gitpython>=3.1.30" "thop>=0.1.1" "tqdm>=4.64.0" "setuptools>=65.5.1" not found, attempting AutoUpdate...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyldavis 3.3.1 requires numpy>=1.20.0, but you have numpy 1.19.5 which is incompatible.
# pyldavis 3.3.1 requires pandas>=1.2.0, but you have pandas 1.1.5 which is incompatible.
# jupyterlab-git 0.11.0 requires nbdime<2.0.0,>=1.1.0, but you have nbdime 2.1.0 which is incompatible.
# earthengine-api 0.1.261 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting tqdm>=4.64.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting setuptools>=65.5.1
#   Downloading setuptools-67.6.1-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.7/site-packages (from gitpython>=3.1.30) (4.0.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.7/site-packages (from gitpython>=3.1.30) (3.7.4.3)
# Requirement already satisfied: torch in /opt/conda/lib/python3.7/site-packages (from thop>=0.1.1) (1.7.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30) (3.0.5)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch->thop>=0.1.1) (0.18.2)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch->thop>=0.1.1) (0.6)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torch->thop>=0.1.1) (1.19.5)
# Installing collected packages: tqdm, thop, setuptools, gitpython
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 49.6.0.post20210108
#     Uninstalling setuptools-49.6.0.post20210108:
#       Successfully uninstalled setuptools-49.6.0.post20210108
#   Attempting uninstall: gitpython
#     Found existing installation: GitPython 3.1.14
#     Uninstalling GitPython-3.1.14:
#       Successfully uninstalled GitPython-3.1.14
# Successfully installed gitpython-3.1.31 setuptools-67.6.1 thop-0.1.1.post2209072238 tqdm-4.65.0
#
# requirements: 4 packages updated per /kaggle/working/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.7.10 torch-1.7.0 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 15.4MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|███████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 125MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7027720 parameters, 7027720 gradients
#
# Transferred 342/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://github.com/ultralytics/yolov5/issues/475 to get started.
# albumentations: WARNING ⚠️ version 1.0.3 is required by YOLOv5, but version 0.5.2 is currently installed
# train: Scanning /kaggle/working/Dataset/labels/train... 4000 images, 0 backgroun
# train: New cache created: /kaggle/working/Dataset/labels/train.cache
# val: Scanning /kaggle/working/Dataset/labels/val... 500 images, 0 backgrounds, 0
# val: New cache created: /kaggle/working/Dataset/labels/val.cache
#
# AutoAnchor: 5.42 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 416 train, 416 val
# Using 1 dataloader workers
# Logging results to runs/train/exp
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/29      1.58G    0.08674    0.03875    0.02597        216        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.494      0.352       0.22     0.0782
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/29      2.51G    0.06124    0.03133    0.01528        238        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422       0.71      0.406      0.435      0.215
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/29      2.51G    0.05714    0.03007   0.009441        248        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.711      0.469      0.427      0.215
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/29      2.51G    0.05008    0.02935   0.007462        225        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.875      0.503      0.556      0.267
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/29      2.51G    0.04625    0.02836   0.006653        247        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.924      0.537      0.587      0.333
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/29      2.51G    0.04352     0.0279   0.005781        260        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.918      0.523      0.582      0.326
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/29      2.51G    0.04091     0.0273   0.005263        192        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.933      0.559      0.599      0.342
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/29      2.51G    0.04012     0.0274   0.005098        190        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.939      0.544      0.598      0.349
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/29      2.51G    0.03847    0.02682   0.004815        186        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422       0.92       0.56      0.606      0.357
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/29      2.51G    0.03783    0.02643   0.004518        229        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.938      0.549      0.605      0.361
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/29      2.51G    0.03685    0.02634    0.00401        200        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.941      0.544      0.605      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/29      2.51G     0.0363    0.02599   0.003966        173        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.942      0.547      0.598      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/29      2.51G    0.03537     0.0256   0.003794        322        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.923      0.555      0.605      0.363
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/29      2.51G    0.03506    0.02588    0.00373        242        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.935       0.55      0.605      0.371
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/29      2.51G    0.03471    0.02493   0.003596        167        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.943      0.555      0.606      0.376
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/29      2.51G    0.03419    0.02546   0.003248        218        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        500       2422      0.611      0.567      0.615       0.38
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/29      2.51G    0.03379    0.02573   0.003422        228        416:

# %% [markdown]
# # Detect (predict)

# %%
#!python detect.py --source /kaggle/working/Dataset/images/test --img-size 416 --conf 0.4 --weights weights.pt 
# !python detect.py --source /kaggle/working/Dataset/images/test  --weights yolov5s.pt --conf 0.25

# %%
# display detected images
from IPython.display import Image

# %%
from glob import glob
import matplotlib.pyplot as plt
testfiles = glob('runs/detect/exp3/*')

img = plt.imread(testfiles[28]) 
plt.imshow(img)    
plt.show
